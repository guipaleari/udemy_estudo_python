# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base = pd.read_csv('co2.csv')
base.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
# Gráfico de dispersão utilizando os atributos conc e uptake, agrupamento pelo type
sns.scatterplot(x=base.conc, y=base.uptake, hue=base.Type)
# Out:
# <AxesSubplot: xlabel='conc', ylabel='uptake'>

# %%
# Seleção de registros específicos da base de dados (Quebec e Mississipi)
q = base.loc[base['Type'] == 'Quebec']
m = base.loc[base['Type'] == 'Mississippi']

# %%
# Subgráfico (1 linha e 2 colunas) mostrando gráficos sobre cada região
plt.figure()

plt.subplot(1, 2, 1)
sns.scatterplot(x=q.conc, y=q.uptake).set_title('Quebec')

plt.subplot(1, 2, 2)
sns.scatterplot(x=m.conc, y=m.uptake).set_title('Mississippi')

plt.tight_layout()

# %%
# Seleção de registros específicos da base de dados (refrigerado e não refrigerado)
ch = base.loc[base['Treatment'] == 'chilled']
nc = base.loc[base['Treatment'] == 'nonchilled']

# %%
# Subgráfico (1 linha e 2 colunas) mostrando gráficos sobre cada situação
plt.figure()

plt.subplot(1, 2, 1)
sns.scatterplot(x=ch.conc, y=ch.uptake).set_title('Chilled')

plt.subplot(1, 2, 2)
sns.scatterplot(x=nc.conc, y=nc.uptake).set_title('Non Chilled')

plt.tight_layout()

# %%
# Carregamento de outro arquivo, câncer de esôfago
base2= pd.read_csv('esoph.csv')
base2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# Gráfico entre os atributos 'alcgp' e 'ncontrols'
sns.catplot(x='alcgp', y='ncontrols', data=base2, jitter=False)

# %%
# Gráfico entre os atributos 'alcgp' e 'ncontrols', com agrupamento
sns.catplot(x='alcgp', y='ncontrols', data=base2, col='tobgp')
