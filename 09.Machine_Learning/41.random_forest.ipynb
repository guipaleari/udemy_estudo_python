# %% [markdown]
# # Randon Forest

# %% [markdown]
# é um poderoso modelo de aprendizado supervisionado usado tanto para problemas de classificação quanto de regressão.
#
# É uma extensão do algoritmo de Árvores de Decisão que melhora a precisão e reduz o overfitting.
#
# Basicamente é um ensemble de várias Árvores de Decisão, onde cada árvore é treinada em um subconjunto aleatório dos dados e das características.
#
# O resultado final é a média ou a maioria dos votos das previsões de todas as árvores.
#
# Esse processo ajuda a aumentar a robustez e a precisão do modelo.

# %% [markdown]
# **Principais Vantagens**
# * **Redução de Overfitting:** Como combina os resultados de múltiplas árvores, tende a ter uma menor variância em comparação com uma única árvore de decisão.
# * **Precisão:** Normalmente resulta em uma precisão maior.
# * **Flexibilidade:** Pode ser usado tanto para classificação quanto para regressão.
# * **Estimativa da Importância das Variáveis:** Pode medir a importância de cada variável no processo de previsão.

# %% [markdown]
# **Passos do Algoritmo Random Forest**
# * **Seleção Aleatória de Dados:** Cada árvore é treinada em um subconjunto aleatório do conjunto de dados de treinamento (com reposição, chamado de bootstrapping).
# * **Seleção Aleatória de Características:** Para cada divisão em uma árvore, um subconjunto aleatório de características é escolhido.
# * **Construção de Árvores de Decisão:** Cada árvore é construída até sua completude ou até atingir um critério de parada (por exemplo, profundidade máxima).
# * **Agregação de Resultados:** Para classificação, o resultado final é a classe mais votada por todas as árvores. Para regressão, é a média das previsões de todas as árvores.

# %% [markdown]
# ❇️ **Exemplo de Classificação com Random Forest**

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Carregar o conjunto de dados Iris
iris = load_iris()
X, y = iris.data, iris.target

# Dividir os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Padronizar os dados
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Criar e treinar o modelo Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

# Fazer previsões
y_pred = rf.predict(X_test)

# Avaliar o modelo
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# Confusion Matrix:
#  [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
# Accuracy: 1.00

# %% [markdown]
# ❇️ **Exemplo de Regressão com Random Forest**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Vamos usar um conjunto de dados de exemplo
data = {
    'X': np.arange(1, 11),
    'y': np.array([1.1, 2.0, 3.2, 4.1, 5.3, 6.2, 7.4, 8.2, 9.3, 10.1])
}
df = pd.DataFrame(data)

# Dividir os dados em conjuntos de treinamento e teste
X = df[['X']]
y = df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Criar e treinar o modelo Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)
rf_regressor.fit(X_train, y_train)

# Fazer previsões
y_pred = rf_regressor.predict(X_test)

# Avaliar o modelo
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 0.31

# %% [markdown]
# ❇️ Exemplo

# %%
from sklearn.preprocessing import LabelEncoder

# %%
credito = pd.read_csv('Credit.csv')

# %%
#apenas valores sem cabeçalho com .values
previsores = credito.iloc[:, 0:20].values 
previsto = credito.iloc[:, 20].values

# %%
le = LabelEncoder()
colunas = [0,2,3,5,6,8,9,11,13,14,16,18,19]
for i in colunas:
    previsores[:, i] = le.fit_transform(previsores[:, i])

# %%
X1, X2, y1, y2 = train_test_split(previsores, 
                                  previsto,
                                  test_size=0.3,
                                  random_state=0)

# %%
floresta = RandomForestClassifier(n_estimators=100)

# %%
floresta.fit(X1, y1)
# Out:
# RandomForestClassifier()

# %%
floresta.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=482816385),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1659491573),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1871374230),
#  DecisionTreeClassifier(max_features='sqrt', random_state=473041430),
#  DecisionTreeClassifier(max_features='sqrt', random_state=141565064),
#  DecisionTreeClassifier(max_features='sqrt', random_state=665931335),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1466662347),
#  DecisionTreeClassifier(max_features='sqrt', random_state=593055620),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1537456616),
#  DecisionTreeClassifier(max_features='sqrt', random_state=643809054),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1785278105),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1321183480),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1738002164),
#  DecisionTreeClassifier(max_features='sqrt', random_state=36721555),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1399742116),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1410247652),
#  DecisionTreeClassifier(max_features='sqrt', random_state=988129215),
#  DecisionTreeClassifier(max_features='sqrt', random_state=861292332),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1612581396),
#  DecisionTreeClassifier(max_features='sqrt', random_state=472466804),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1747966498),
#  DecisionTreeClassifier(max_features='sqrt', random_state=102318000),
#  DecisionTreeClassifier(max_features='sqrt', random_state=834236281),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1365917309),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1429954212),
#  DecisionTreeClassifier(max_features='sqrt', random_state=737564086),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1390372601),
#  DecisionTreeClassifier(max_features='sqrt', random_state=912272570),
#  DecisionTreeClassifier(max_features='sqrt', random_state=190938378),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2002374186),
#  DecisionTreeClassifier(max_features='sqrt', random_state=540862129),
#  DecisionTreeClassifier(max_features='sqrt', random_state=185205598),
#  DecisionTreeClassifier(max_features='sqrt', random_state=879406755),
#  DecisionTreeClassifier(max_features='sqrt', random_state=936201324),
#  DecisionTreeClassifier(max_features='sqrt', random_state=27058829),
#  DecisionTreeClassifier(max_features='sqrt', random_state=354927554),
#  DecisionTreeClassifier(max_features='sqrt', random_state=387054631),
#  DecisionTreeClassifier(max_features='sqrt', random_state=138284531),
#  DecisionTreeClassifier(max_features='sqrt', random_state=459150118),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1475702870),
#  DecisionTreeClassifier(max_features='sqrt', random_state=562214960),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1022516176),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1418627449),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1233288558),
#  DecisionTreeClassifier(max_features='sqrt', random_state=37210818),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1539959529),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1157686592),
#  DecisionTreeClassifier(max_features='sqrt', random_state=991337022),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1203450417),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1246299244),
#  DecisionTreeClassifier(max_features='sqrt', random_state=385736369),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1988267105),
#  DecisionTreeClassifier(max_features='sqrt', random_state=68569232),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1927926216),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1171562437),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1557991349),
#  DecisionTreeClassifier(max_features='sqrt', random_state=6726185),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1298875850),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1059362809),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1238182800),
#  DecisionTreeClassifier(max_features='sqrt', random_state=32138425),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1807377248),
#  DecisionTreeClassifier(max_features='sqrt', random_state=527324431),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1622810021),
#  DecisionTreeClassifier(max_features='sqrt', random_state=852751145),
#  DecisionTreeClassifier(max_features='sqrt', random_state=121811047),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1346740979),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2016719222),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1695721645),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1435023923),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1245813108),
#  DecisionTreeClassifier(max_features='sqrt', random_state=498083370),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1220982491),
#  DecisionTreeClassifier(max_features='sqrt', random_state=780956566),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1980323279),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1326460078),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1297118155),
#  DecisionTreeClassifier(max_features='sqrt', random_state=852530314),
#  DecisionTreeClassifier(max_features='sqrt', random_state=450647983),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2090784312),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1894648018),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1092645014),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1486366443),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1930217987),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1216006977),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1984973673),
#  DecisionTreeClassifier(max_features='sqrt', random_state=343620764),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1455217403),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2004635903),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1504968333),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1600382280),
#  DecisionTreeClassifier(max_features='sqrt', random_state=256962883),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1822285574),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1511778685),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1776305914),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2084622015),
#  DecisionTreeClassifier(max_features='sqrt', random_state=744012164),
#  DecisionTreeClassifier(max_features='sqrt', random_state=12722154),
#  DecisionTreeClassifier(max_features='sqrt', random_state=553902901),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1215597515)]

# %%
floresta.predict(X2)
# Out:
# array(['bad', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'bad', 'bad',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'bad', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'bad', 'bad', 'good', 'good', 'bad', 'bad',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'bad', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'bad', 'bad', 'good', 'good',
#        'good', 'bad', 'good', 'bad', 'good', 'good', 'good', 'bad', 'bad',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'bad', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'good', 'good', 'good', 'good', 'bad', 'bad',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'bad', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'bad', 'bad'],
#       dtype=object)

# %%
confusion_matrix(y2, floresta.predict(X2))
# Out:
# array([[ 38,  48],
#        [ 19, 195]])

# %%
accuracy_score(y2, floresta.predict(X2))
# Out:
# 0.7766666666666666
